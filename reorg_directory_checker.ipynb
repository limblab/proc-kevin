# %% [markdown]
# ## Import necessary libraries

# %%
from scipy.io import loadmat
from matplotlib import pyplot as plt
from numpy import savetxt

# %% [markdown]
# Load data

# %%
directoryList = loadmat('C:\\Users\\17204\\Downloads\\fileReorganizationData.mat')


print(directoryList['skippedFileList'])
# Out:
# [[(array(['TikiC017 (2).nev'], dtype='<U16'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120113'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['TikiC004-02.nev'], dtype='<U15'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120207'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['TikiC005-02.nev'], dtype='<U15'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120207'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['TikiC012-02.nev'], dtype='<U15'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120207'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['TikiC008-02.nev'], dtype='<U15'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120207'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['TikiC007-02.nev'], dtype='<U15'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120207'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['TikiC003-02.nev'], dtype='<U15'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120207'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['TikiC009-02.nev'], dtype='<U15'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120207'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['TikiC001-02.nev'], dtype='<U15'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120207'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['TikiC010-02.nev'], dtype='<U15'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120207'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['TikiC011-02.nev'], dtype='<U15'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120207'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['TikiC002-02.nev'], dtype='<U15'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120207'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['Tiki_2011-04-20_RW_001-s.nev'], dtype='<U28'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['Tiki_2011-06-08_RW_001-xcr-5-10-single_units.nev'], dtype='<U48'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['Tiki_2011-04-28_BC_001-s_multiunit.nev'], dtype='<U38'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['Tiki_2011-06-15_RW_001-xcr-5-10-single_units.nev'], dtype='<U48'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['Tiki_2011-06-02_RW_001-xcr-5-5-single_units.nev'], dtype='<U47'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['Tiki_2011-06-08_RW_001-single_units.nev'], dtype='<U39'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['Tiki_2011-06-13_RW_001-xcr-5-10-single_units.nev'], dtype='<U48'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['Tiki_2011-06-02_RW_001-xcr-5-5-multiunit.nev'], dtype='<U44'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['Tiki_2011-04-27_BC_002-s_multiunit.nev'], dtype='<U38'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['Tiki_2011-05-19_RW_001-s_thres.nev'], dtype='<U34'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['Tiki_2011-04-27_BC_001-s_multiunit.nev'], dtype='<U38'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['Tiki_2011-03-11_RW_001-s_3units.nev'], dtype='<U35'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['Tiki_2011-04-27_BC_003-s_multiunit.nev'], dtype='<U38'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['Tiki_2011-05-17_RW_001-s_thres.nev'], dtype='<U34'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['Tiki_2011-05-17_RW_001-s_thres2.nev'], dtype='<U35'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['Tiki_2011-03-22_BC_003-s_multiunit.nev'], dtype='<U38'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['Tiki_2011-05-17_BC_001-s_thres.nev'], dtype='<U34'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['Tiki_2011-06-21_RW_001-xcr-5-10-single_units.nev'], dtype='<U48'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['Tiki_2011-06-02_RW_001-xcr-5-5.nev'], dtype='<U34'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['Tiki_2011-04-28_BC_002-s_multiunit.nev'], dtype='<U38'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['TikiC005-01.nev'], dtype='<U15'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120129'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['TikiC002-01.nev'], dtype='<U15'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120129'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['TikiC011-01.nev'], dtype='<U15'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120129'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['TikiC007-01.nev'], dtype='<U15'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120129'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['TikiC004-01.nev'], dtype='<U15'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120129'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['TikiC006-01.nev'], dtype='<U15'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120129'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['TikiC009-01.nev'], dtype='<U15'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120129'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['TikiC001-01.nev'], dtype='<U15'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120129'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['TikiC003-01.nev'], dtype='<U15'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120129'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['TikiC010-01.nev'], dtype='<U15'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120129'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['TikiC012-01.nev'], dtype='<U15'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120129'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['TikiC008-01.nev'], dtype='<U15'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120129'],
#         dtype='<U108'), array(['Unknown error -- skipped due to try/catch exception'],
#         dtype='<U51'))
#   (array(['tiki_rw029-032-sj.plx'], dtype='<U21'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array([], shape=(1, 0), dtype=float64))
#   (array(['tiki_rw029-032-sj.plx'], dtype='<U21'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110405'],
#         dtype='<U108'), array(["Undefined function or variable 'ME'."], dtype='<U36'))
#   (array(['Tiki Bumps002.plx'], dtype='<U17'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['Index exceeds matrix dimensions.'], dtype='<U32'))
#   (array(['tiki_rw004-xcr.plx'], dtype='<U18'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['file does not exist'], dtype='<U19'))
#   (array(['Tiki_BS_forces_002.plx'], dtype='<U22'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110929'],
#         dtype='<U108'), array(['file does not exist'], dtype='<U19'))
#   (array(['Tiki_BS_forces_004.plx'], dtype='<U22'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110929'],
#         dtype='<U108'), array(['file does not exist'], dtype='<U19'))
#   (array(['Tiki_BS_forces_001.plx'], dtype='<U22'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110929'],
#         dtype='<U108'), array(['file does not exist'], dtype='<U19'))
#   (array(['tiki_rw029-032-sj.plx'], dtype='<U21'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['file does not exist'], dtype='<U19'))
#   (array(['Tiki_S1_b_005-s.plx'], dtype='<U19'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['file does not exist'], dtype='<U19'))
#   (array(['Tiki Bumps001.plx'], dtype='<U17'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['Index exceeds matrix dimensions.'], dtype='<U32'))
#   (array(['Tiki_S1_b_010-s.plx'], dtype='<U19'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['file does not exist'], dtype='<U19'))
#   (array(['Tiki Bumps003.plx'], dtype='<U17'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['Index exceeds matrix dimensions.'], dtype='<U32'))
#   (array(['Tiki_S1_b_015-s.plx'], dtype='<U19'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120608'],
#         dtype='<U108'), array(['file does not exist'], dtype='<U19'))
#   (array(['tiki_rw004-s.plx'], dtype='<U16'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110929'],
#         dtype='<U108'), array(['file does not exist'], dtype='<U19'))
#   (array(['Tiki_RW_LowThreshold_1-01.plx'], dtype='<U29'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110929'],
#         dtype='<U108'), array(['file does not exist'], dtype='<U19'))
#   (array(['Tiki_BC_no_spikes_032_sub.plx'], dtype='<U29'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110929'],
#         dtype='<U108'), array(['file does not exist'], dtype='<U19'))
#   (array(['Tiki_RW_009_sub_spl_t002.plx'], dtype='<U28'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110929'],
#         dtype='<U108'), array(['file does not exist'], dtype='<U19'))
#   (array(['tiki_rw006-s.plx'], dtype='<U16'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110929'],
#         dtype='<U108'), array(['file does not exist'], dtype='<U19'))
#   (array(['Tiki_BS_forces_002.plx'], dtype='<U22'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110929'],
#         dtype='<U108'), array(['file does not exist'], dtype='<U19'))
#   (array(['Tiki_BS_forces_004.plx'], dtype='<U22'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110929'],
#         dtype='<U108'), array(['file does not exist'], dtype='<U19'))
#   (array(['Tiki_BS_forces_001.plx'], dtype='<U22'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110929'],
#         dtype='<U108'), array(['file does not exist'], dtype='<U19'))
#   (array(['Tiki_RW_LowThreshold_1-02.plx'], dtype='<U29'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110929'],
#         dtype='<U108'), array(['file does not exist'], dtype='<U19'))
#   (array(['Tiki_RW_009_sub.plx'], dtype='<U19'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110929'],
#         dtype='<U108'), array(['file does not exist'], dtype='<U19'))
#   (array(['tiki_rw029-032-sj.plx'], dtype='<U21'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['file does not exist'], dtype='<U19'))
#   (array(['Tiki_BC_no_spikes_037_sub.plx'], dtype='<U29'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110929'],
#         dtype='<U108'), array(['file does not exist'], dtype='<U19'))
#   (array(['Tiki_RW_009_sub_spl_t001.plx'], dtype='<U28'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110929'],
#         dtype='<U108'), array(['file does not exist'], dtype='<U19'))
#   (array(['tiki_rw026_s.plx'], dtype='<U16'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110929'],
#         dtype='<U108'), array(['file does not exist'], dtype='<U19'))
#   (array(['tiki_rw018-s.plx'], dtype='<U16'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110929'],
#         dtype='<U108'), array(['file does not exist'], dtype='<U19'))
#   (array(['Tiki_BC_no_spikes_029_sub.plx'], dtype='<U29'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110929'],
#         dtype='<U108'), array(['file does not exist'], dtype='<U19'))
#   (array(['Tiki_BC_no_spikes_033_sub.plx'], dtype='<U29'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110929'],
#         dtype='<U108'), array(['file does not exist'], dtype='<U19'))
#   (array(['Tiki_BS_forces_002.plx'], dtype='<U22'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110929'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['tiki_rw_006.mat'], dtype='<U15'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110929'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['Tiki_BS_forces_004.plx'], dtype='<U22'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110929'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['Tiki_BS_forces_001.plx'], dtype='<U22'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110929'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['Tiki - S1 Array 2009-07-20.exp'], dtype='<U30'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['Tiki Bumps002.plx'], dtype='<U17'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['Tiki - S1 Array 2009-08-28.exp'], dtype='<U30'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['Tiki - S1 Array 2009-08-19.exp'], dtype='<U30'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['Tiki_2011-03-03_RW.ccf'], dtype='<U22'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['Tiki_processed_mri.mat'], dtype='<U22'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['Tiki - S1 Array 2010-01-20.exp'], dtype='<U30'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['Tiki Bumps003.mat'], dtype='<U17'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['Tiki_2011-03-15_BC.ccf'], dtype='<U22'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['Tiki_2011-03-09_RW.ccf'], dtype='<U22'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['Tiki - S1 Array 2010-03-08.exp'], dtype='<U30'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['Tiki - S1 Array 2009-11-30.exp'], dtype='<U30'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['Tiki - S1 Array 2010-03-22.exp'], dtype='<U30'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['Tiki_2011-03-07_RW.ccf'], dtype='<U22'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['tiki_rw029-032-sj.plx'], dtype='<U21'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['Tiki_mri_stereotax.mat'], dtype='<U22'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['Tiki - S1 Array 2009-11-04.exp'], dtype='<U30'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['Tiki Bumps001.plx'], dtype='<U17'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['Tiki - S1 Array 2009-12-02.exp'], dtype='<U30'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['Tiki_2011-03-08_RW.ccf'], dtype='<U22'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['Tiki Bumps003.plx'], dtype='<U17'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['Ricardo_BC_002.mat'], dtype='<U18'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['Tiki - S1 Array 2010-03-31.exp'], dtype='<U30'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20110930'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))
#   (array(['Ch61Tiki001.mat'], dtype='<U15'), array(['\\\\fsmresfiles.fsm.northwestern.edu\\fsmresfiles\\Basic_Sciences\\Phys\\L_MillerLab\\data\\Tiki_4C1_target\\20120206'],
#         dtype='<U108'), array(['No associated nev found'], dtype='<U23'))                                                                                                    ]]
